# %%
print("merhaba dünya")
# Out:
# merhaba dünya

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4])
y=np.sqrt(x)

plt.plot(x,y, label="karekök")
plt.legend()
plt.show()
